# %% [markdown]
# # Basic Examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from sigmaepsilon.plotting.mpl import parallel

colors = np.random.rand(150, 3)
labels = [str(i) for i in range(10)]
values = [np.random.rand(150) for i in range(10)]
fig = parallel(values, labels=labels, padding=0.05, lw=0.2,
               colors=colors, title='Parallel Plot with Random Data')

# %%
from sigmaepsilon.plotting.mpl import aligned_parallel

labels = ['a', 'b', 'c']
values = np.array([np.random.rand(150) for _ in labels]).T
datapos = np.linspace(-1, 1, 150)

fig = aligned_parallel(values, datapos, labels=labels, yticks=[-1, 1], y=0.8,
                       xticksrotation=0, vlines=[0., 1.], figsize=(7, 5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 values = np.array([np.random.rand(150) for _ in labels]).T
#       5 datapos = np.linspace(-1, 1, 150)
# ----> 7 fig = aligned_parallel(values, datapos, labels=labels, yticks=[-1, 1], y=0.8,
#       8                        xticksrotation=0, vlines=[0., 1.], figsize=(7, 5))
#
# File D:\Projects\SigmaEpsilon\sigmaepsilon.plotting.mpl\src\sigmaepsilon\plotting\mpl\parallel.py:429, in aligned_parallel(data, datapos, yticks, labels, sharelimits, texlabels, xticksrotation, suptitle, slider, slider_label, hlines, vlines, y, xoffset, yoffset, **kwargs)
#     427     slider_.on_changed(_update_slider)
#     428     fig._slider = slider_  # to keep reference, otherwise slider is not responsive
# --> 429 _set_yval(y0)
#     431 return fig
#
# ...

# %%
# %matplotlib qt
